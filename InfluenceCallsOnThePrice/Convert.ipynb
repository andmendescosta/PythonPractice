# %%
import pandas as pd

# %%
regions = pd.read_csv("./data/regions.csv", dtype={"number" : "str"},sep=",")

# %%
regions
# Out:
#                                        FID  GID  COD_BAIRRO  \
# 0    Bairros.fid-2be50750_153af4824fe_2bc9    6          88
# 1    Bairros.fid-2be50750_153af4824fe_2bca   21         110
# 2    Bairros.fid-2be50750_153af4824fe_2bcb   22         111
# 3    Bairros.fid-2be50750_153af4824fe_2bcc   23          93
# 4    Bairros.fid-2be50750_153af4824fe_2bcd   17           6
# 5    Bairros.fid-2be50750_153af4824fe_2bce   16           5
# 6    Bairros.fid-2be50750_153af4824fe_2bcf   18          52
# 7    Bairros.fid-2be50750_153af4824fe_2bd0   26          69
# 8    Bairros.fid-2be50750_153af4824fe_2bd1   28          68
# 9    Bairros.fid-2be50750_153af4824fe_2bd2   48          70
# 10   Bairros.fid-2be50750_153af4824fe_2bd3   52          57
# 11   Bairros.fid-2be50750_153af4824fe_2bd4   80         100
# 12   Bairros.fid-2be50750_153af4824fe_2bd5   88          24
# 13   Bairros.fid-2be50750_153af4824fe_2bd6   96          89
# 14   Bairros.fid-2be50750_153af4824fe_2bd7   98         114
# ...

# %%
regions["THE_GEOM"] = regions["THE_GEOM"].str.replace(' ', '==')
regions["THE_GEOM"] = regions["THE_GEOM"].str.replace(',', ' ')
regions["THE_GEOM"] = regions["THE_GEOM"].str.replace('==', ',')

# %%
regions.to_csv("./data/regions2.csv", index=None)
